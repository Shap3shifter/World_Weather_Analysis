# %%
# %matplotlib inline

# %%
#Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
import random
from datetime import datetime

# %%
#Import the API key
from config import weather_api_key

# %%
#Starting URL for Weather Map API call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=feb61a95c051936b868ddd445f0a3849

# %%
#Create a set of random lat/long combos.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
#Add lat/longs to a list of coordinates
coordinates = list(lats_lngs)

# %%
#Create a list to hold the cities.
cities = []

#Identify the nearest city per lat/long combo.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
#Print the city count 
len(cities)
# Out:
# 752

# %%
#Create an empty list to hold the weather data.
city_data = []

#Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters.
record_count = 1
set_count = 1

#Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    #Group cities in set of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    #Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    #Run an API request for each of the cities. 
    try: 
            #Parse the JSON 
            city_weather = requests.get(city_url).json()
            #Get the data
            city_lat = city_weather['coord']['lat']
            city_lng = city_weather['coord']['lon']
            city_max_temp = city_weather['main']['temp_max']
            city_humidity = city_weather['main']['humidity']
            city_description = city_weather['weather'][0]['description']
            city_clouds = city_weather['clouds']['all']
            city_wind = city_weather['wind']['speed']
            city_country = city_weather['sys']['country']
            #Append the city information into the city_data list.
            city_data.append({"City": city.title(), 
                             "Country": city_country,
                             "Lat": city_lat,
                             "Lng": city_lng,
                             "Max Temp": city_max_temp,
                             "Humidity": city_humidity,
                             "Cloudiness": city_clouds,
                             "Wind Speed": city_wind,
                             "Current Description": city_description})
            
    except:
            print("City not found. Skipping...")
            pass
    
    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port elizabeth
# Processing Record 2 of Set 1 | jiazi
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | hami
# Processing Record 5 of Set 1 | lincoln
# Processing Record 6 of Set 1 | asau
# Processing Record 7 of Set 1 | butaritari
# Processing Record 8 of Set 1 | antalaha
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | torbay
# Processing Record 11 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 1 | jiayuguan
# Processing Record 13 of Set 1 | lerwick
# Processing Record 14 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 1 | yellowknife
# Processing Record 16 of Set 1 | poum
# Processing Record 17 of Set 1 | auki
# Processing Record 18 of Set 1 | bicas
# Processing Record 19 of Set 1 | tuktoyaktuk
# Processing Record 20 of Set 1 | saint-philippe
# Processing Record 21 of Set 1 | sitka
# Processing Record 22 of Set 1 | lebu
# Processing Record 23 of Set 1 | nemuro
# Processing Record 24 of Set 1 | barrow
# Processing Record 25 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | ponta do sol
# Processing Record 28 of Set 1 | kieta
# Processing Record 29 of Set 1 | kungurtug
# Processing Record 30 of Set 1 | millinocket
# Processing Record 31 of Set 1 | kodiak
# Processing Record 32 of Set 1 | port blair
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | aksu
# Processing Record 35 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 1 | tommot
# Processing Record 37 of Set 1 | starkville
# Processing Record 38 of Set 1 | qaanaaq
# Processing Record 39 of Set 1 | gejiu
# Processing Record 40 of Set 1 | puerto ayora
# Processing Record 41 of Set 1 | pitimbu
# Processing Record 42 of Set 1 | okhotsk
# Processing Record 43 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 1 | comodoro rivadavia
# Processing Record 45 of Set 1 | eufaula
# Processing Record 46 of Set 1 | avarua
# Processing Record 47 of Set 1 | puerto carreno
# Processing Record 48 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 1 | carnarvon
# Processing Record 50 of Set 1 | mar del plata
# Processing Record 1 of Set 2 | upernavik
# Processing Record 2 of Set 2 | kahului
# Processing Record 3 of Set 2 | punta arenas
# Processing Record 4 of Set 2 | kapaa
# Processing Record 5 of Set 2 | nyurba
# Processing Record 6 of Set 2 | touros
# Processing Record 7 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 8 of Set 2 | college
# Processing Record 9 of Set 2 | hermanus
# Processing Record 10 of Set 2 | east london
# Processing Record 11 of Set 2 | bandarbeyla
# Processing Record 12 of Set 2 | hobart
# Processing Record 13 of Set 2 | vaini
# Processing Record 14 of Set 2 | vardo
# Processing Record 15 of Set 2 | yaan
# Processing Record 16 of Set 2 | lagoa
# Processing Record 17 of Set 2 | hambantota
# Processing Record 18 of Set 2 | dikson
# Processing Record 19 of Set 2 | tananger
# Processing Record 20 of Set 2 | feira nova
# Processing Record 21 of Set 2 | mount isa
# Processing Record 22 of Set 2 | iqaluit
# Processing Record 23 of Set 2 | bluff
# Processing Record 24 of Set 2 | souillac
# Processing Record 25 of Set 2 | shchelyayur
# City not found. Skipping...
# Processing Record 26 of Set 2 | sakaraha
# Processing Record 27 of Set 2 | fortuna
# Processing Record 28 of Set 2 | kulhudhuffushi
# Processing Record 29 of Set 2 | mataura
# Processing Record 30 of Set 2 | bushehr
# Processing Record 31 of Set 2 | hasaki
# Processing Record 32 of Set 2 | arraial do cabo
# Processing Record 33 of Set 2 | pacific grove
# Processing Record 34 of Set 2 | ushuaia
# Processing Record 35 of Set 2 | cabo san lucas
# Processing Record 36 of Set 2 | caucaia
# Processing Record 37 of Set 2 | teguise
# Processing Record 38 of Set 2 | da nang
# Processing Record 39 of Set 2 | sicuani
# Processing Record 40 of Set 2 | kapit
# Processing Record 41 of Set 2 | nome
# Processing Record 42 of Set 2 | ancud
# Processing Record 43 of Set 2 | new norfolk
# Processing Record 44 of Set 2 | puerto del rosario
# Processing Record 45 of Set 2 | victoria
# Processing Record 46 of Set 2 | thompson
# Processing Record 47 of Set 2 | cidreira
# Processing Record 48 of Set 2 | ilulissat
# Processing Record 49 of Set 2 | jamestown
# Processing Record 50 of Set 2 | longyearbyen
# Processing Record 1 of Set 3 | fairbanks
# Processing Record 2 of Set 3 | acari
# Processing Record 3 of Set 3 | tasiilaq
# Processing Record 4 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 3 | ahuimanu
# Processing Record 6 of Set 3 | katsiveli
# City not found. Skipping...
# Processing Record 7 of Set 3 | esperance
# Processing Record 8 of Set 3 | duekoue
# Processing Record 9 of Set 3 | killybegs
# Processing Record 10 of Set 3 | mandalgovi
# Processing Record 11 of Set 3 | petershagen
# Processing Record 12 of Set 3 | salalah
# Processing Record 13 of Set 3 | albany
# Processing Record 14 of Set 3 | alofi
# Processing Record 15 of Set 3 | nortelandia
# Processing Record 16 of Set 3 | qaqortoq
# Processing Record 17 of Set 3 | saldanha
# Processing Record 18 of Set 3 | san patricio
# Processing Record 19 of Set 3 | castro
# Processing Record 20 of Set 3 | torremolinos
# Processing Record 21 of Set 3 | parit buntar
# Processing Record 22 of Set 3 | hengyang
# Processing Record 23 of Set 3 | talnakh
# Processing Record 24 of Set 3 | chivay
# Processing Record 25 of Set 3 | faanui
# Processing Record 26 of Set 3 | bredasdorp
# Processing Record 27 of Set 3 | tura
# Processing Record 28 of Set 3 | novovasylivka
# Processing Record 29 of Set 3 | praxedis guerrero
# Processing Record 30 of Set 3 | saint-pierre
# Processing Record 31 of Set 3 | estevan
# Processing Record 32 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 3 | bratsk
# Processing Record 34 of Set 3 | gangotri
# City not found. Skipping...
# Processing Record 35 of Set 3 | wanaka
# Processing Record 36 of Set 3 | chapais
# Processing Record 37 of Set 3 | yagodnoye
# Processing Record 38 of Set 3 | maniitsoq
# Processing Record 39 of Set 3 | lorengau
# Processing Record 40 of Set 3 | port alfred
# Processing Record 41 of Set 3 | tsabong
# Processing Record 42 of Set 3 | lazaro cardenas
# Processing Record 43 of Set 3 | sandnessjoen
# Processing Record 44 of Set 3 | vila velha
# Processing Record 45 of Set 3 | belaya gora
# Processing Record 46 of Set 3 | felidhoo
# City not found. Skipping...
# Processing Record 47 of Set 3 | narsaq
# Processing Record 48 of Set 3 | klaksvik
# Processing Record 49 of Set 3 | saskylakh
# Processing Record 50 of Set 3 | nikolskoye
# Processing Record 1 of Set 4 | roesti
# Processing Record 2 of Set 4 | bambous virieux
# Processing Record 3 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 4 | ono
# Processing Record 5 of Set 4 | kununurra
# Processing Record 6 of Set 4 | lavrentiya
# Processing Record 7 of Set 4 | tuatapere
# Processing Record 8 of Set 4 | marzuq
# Processing Record 9 of Set 4 | kavieng
# Processing Record 10 of Set 4 | tessalit
# Processing Record 11 of Set 4 | bayan
# Processing Record 12 of Set 4 | arlit
# Processing Record 13 of Set 4 | shemonaikha
# Processing Record 14 of Set 4 | brunswick
# Processing Record 15 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 16 of Set 4 | lakatoro
# Processing Record 17 of Set 4 | sibu
# Processing Record 18 of Set 4 | hamilton
# Processing Record 19 of Set 4 | mahebourg
# Processing Record 20 of Set 4 | tual
# Processing Record 21 of Set 4 | ridgecrest
# Processing Record 22 of Set 4 | coquimbo
# Processing Record 23 of Set 4 | pierre
# Processing Record 24 of Set 4 | marawi
# Processing Record 25 of Set 4 | saint-louis
# Processing Record 26 of Set 4 | collie
# Processing Record 27 of Set 4 | tsaratanana
# Processing Record 28 of Set 4 | kruisfontein
# Processing Record 29 of Set 4 | kuytun
# Processing Record 30 of Set 4 | krasnousolskiy
# City not found. Skipping...
# Processing Record 31 of Set 4 | kasama
# Processing Record 32 of Set 4 | hithadhoo
# Processing Record 33 of Set 4 | umea
# Processing Record 34 of Set 4 | deputatskiy
# Processing Record 35 of Set 4 | zavolzhsk
# Processing Record 36 of Set 4 | grand forks
# Processing Record 37 of Set 4 | leninskoye
# Processing Record 38 of Set 4 | san policarpo
# Processing Record 39 of Set 4 | rosario oeste
# Processing Record 40 of Set 4 | torbat-e jam
# Processing Record 41 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 4 | hofn
# Processing Record 43 of Set 4 | cascais
# Processing Record 44 of Set 4 | tiksi
# Processing Record 45 of Set 4 | chabahar
# Processing Record 46 of Set 4 | sao filipe
# Processing Record 47 of Set 4 | lompoc
# Processing Record 48 of Set 4 | diu
# Processing Record 49 of Set 4 | tautira
# Processing Record 50 of Set 4 | la ronge
# Processing Record 1 of Set 5 | cururupu
# Processing Record 2 of Set 5 | opuwo
# Processing Record 3 of Set 5 | chokurdakh
# Processing Record 4 of Set 5 | goya
# Processing Record 5 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 5 | kamloops
# Processing Record 7 of Set 5 | luangwa
# Processing Record 8 of Set 5 | itacoatiara
# Processing Record 9 of Set 5 | isangel
# Processing Record 10 of Set 5 | vao
# Processing Record 11 of Set 5 | kaitangata
# Processing Record 12 of Set 5 | chuy
# Processing Record 13 of Set 5 | ribeira grande
# Processing Record 14 of Set 5 | khomeyn
# Processing Record 15 of Set 5 | thunder bay
# Processing Record 16 of Set 5 | belmonte
# Processing Record 17 of Set 5 | harper
# Processing Record 18 of Set 5 | guajara-mirim
# City not found. Skipping...
# Processing Record 19 of Set 5 | ixtapa
# Processing Record 20 of Set 5 | port-de-paix
# City not found. Skipping...
# Processing Record 21 of Set 5 | vanavara
# Processing Record 22 of Set 5 | beinamar
# Processing Record 23 of Set 5 | arman
# Processing Record 24 of Set 5 | iwanai
# Processing Record 25 of Set 5 | chunskiy
# Processing Record 26 of Set 5 | aklavik
# Processing Record 27 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 5 | iquitos
# Processing Record 29 of Set 5 | ahumada
# City not found. Skipping...
# Processing Record 30 of Set 5 | airai
# Processing Record 31 of Set 5 | glomfjord
# Processing Record 32 of Set 5 | roald
# Processing Record 33 of Set 5 | porterville
# Processing Record 34 of Set 5 | georgetown
# Processing Record 35 of Set 5 | kadipaten
# Processing Record 36 of Set 5 | henties bay
# Processing Record 37 of Set 5 | gzhatsk
# City not found. Skipping...
# Processing Record 38 of Set 5 | sorong
# Processing Record 39 of Set 5 | los llanos de aridane
# Processing Record 40 of Set 5 | ketchikan
# Processing Record 41 of Set 5 | ninotsminda
# Processing Record 42 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 43 of Set 5 | vestmannaeyjar
# Processing Record 44 of Set 5 | moose factory
# Processing Record 45 of Set 5 | plettenberg bay
# Processing Record 46 of Set 5 | geraldton
# Processing Record 47 of Set 5 | rio grande
# Processing Record 48 of Set 5 | grand gaube
# Processing Record 49 of Set 5 | blythe
# Processing Record 50 of Set 5 | tsumeb
# Processing Record 1 of Set 6 | kumylzhenskaya
# Processing Record 2 of Set 6 | shenxian
# Processing Record 3 of Set 6 | kirakira
# Processing Record 4 of Set 6 | poya
# Processing Record 5 of Set 6 | megion
# Processing Record 6 of Set 6 | khatanga
# Processing Record 7 of Set 6 | portland
# Processing Record 8 of Set 6 | bengkulu
# Processing Record 9 of Set 6 | arequipa
# Processing Record 10 of Set 6 | ahome
# Processing Record 11 of Set 6 | severo-kurilsk
# Processing Record 12 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 6 | kemijarvi
# Processing Record 14 of Set 6 | katsuura
# Processing Record 15 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 6 | roswell
# Processing Record 17 of Set 6 | sovetskoye
# Processing Record 18 of Set 6 | brewster
# Processing Record 19 of Set 6 | praia da vitoria
# Processing Record 20 of Set 6 | ciudad bolivar
# Processing Record 21 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 22 of Set 6 | itoman
# Processing Record 23 of Set 6 | tabas
# Processing Record 24 of Set 6 | simao
# Processing Record 25 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 26 of Set 6 | bacolod
# Processing Record 27 of Set 6 | frankfort
# Processing Record 28 of Set 6 | cockburn town
# Processing Record 29 of Set 6 | beringovskiy
# Processing Record 30 of Set 6 | lyubim
# Processing Record 31 of Set 6 | areia branca
# Processing Record 32 of Set 6 | great falls
# Processing Record 33 of Set 6 | raga
# Processing Record 34 of Set 6 | hilo
# Processing Record 35 of Set 6 | koraput
# Processing Record 36 of Set 6 | opotiki
# Processing Record 37 of Set 6 | luderitz
# Processing Record 38 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 6 | limulunga
# Processing Record 40 of Set 6 | san andres
# Processing Record 41 of Set 6 | meulaboh
# Processing Record 42 of Set 6 | derzhavinsk
# Processing Record 43 of Set 6 | nanortalik
# Processing Record 44 of Set 6 | miranda
# Processing Record 45 of Set 6 | cabra
# Processing Record 46 of Set 6 | bubaque
# Processing Record 47 of Set 6 | broken hill
# Processing Record 48 of Set 6 | vigrestad
# Processing Record 49 of Set 6 | puri
# Processing Record 50 of Set 6 | carutapera
# Processing Record 1 of Set 7 | vila franca do campo
# Processing Record 2 of Set 7 | burla
# Processing Record 3 of Set 7 | sarangani
# Processing Record 4 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 7 | rawson
# Processing Record 6 of Set 7 | atar
# Processing Record 7 of Set 7 | alugan
# Processing Record 8 of Set 7 | gorele
# Processing Record 9 of Set 7 | dire
# Processing Record 10 of Set 7 | harnosand
# Processing Record 11 of Set 7 | krasnoarmeysk
# Processing Record 12 of Set 7 | shubarshi
# Processing Record 13 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 14 of Set 7 | pauini
# Processing Record 15 of Set 7 | codrington
# Processing Record 16 of Set 7 | norman wells
# Processing Record 17 of Set 7 | galle
# Processing Record 18 of Set 7 | gat
# Processing Record 19 of Set 7 | umm lajj
# Processing Record 20 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 7 | mehran
# Processing Record 22 of Set 7 | tukrah
# Processing Record 23 of Set 7 | ekuvukeni
# Processing Record 24 of Set 7 | san cristobal
# Processing Record 25 of Set 7 | taksimo
# Processing Record 26 of Set 7 | czluchow
# Processing Record 27 of Set 7 | armacao dos buzios
# City not found. Skipping...
# Processing Record 28 of Set 7 | sinnamary
# Processing Record 29 of Set 7 | dudhani
# Processing Record 30 of Set 7 | wolbrom
# Processing Record 31 of Set 7 | sambava
# Processing Record 32 of Set 7 | port keats
# Processing Record 33 of Set 7 | provideniya
# Processing Record 34 of Set 7 | te anau
# Processing Record 35 of Set 7 | daru
# Processing Record 36 of Set 7 | kiama
# Processing Record 37 of Set 7 | sakakah
# Processing Record 38 of Set 7 | quelimane
# Processing Record 39 of Set 7 | talcahuano
# Processing Record 40 of Set 7 | tazovskiy
# Processing Record 41 of Set 7 | turukhansk
# Processing Record 42 of Set 7 | gueugnon
# Processing Record 43 of Set 7 | areosa
# Processing Record 44 of Set 7 | fengrun
# Processing Record 45 of Set 7 | basco
# Processing Record 46 of Set 7 | bandipur
# Processing Record 47 of Set 7 | impfondo
# Processing Record 48 of Set 7 | beloha
# Processing Record 49 of Set 7 | anshun
# Processing Record 50 of Set 7 | port hardy
# Processing Record 1 of Set 8 | ngemplak
# Processing Record 2 of Set 8 | tabou
# Processing Record 3 of Set 8 | inongo
# Processing Record 4 of Set 8 | bogalusa
# Processing Record 5 of Set 8 | naze
# Processing Record 6 of Set 8 | laguna
# Processing Record 7 of Set 8 | whitehorse
# Processing Record 8 of Set 8 | regina
# Processing Record 9 of Set 8 | haimen
# Processing Record 10 of Set 8 | humberto de campos
# Processing Record 11 of Set 8 | diffa
# Processing Record 12 of Set 8 | bogo
# Processing Record 13 of Set 8 | ormara
# Processing Record 14 of Set 8 | marsh harbour
# Processing Record 15 of Set 8 | bantogon
# Processing Record 16 of Set 8 | kanalia
# Processing Record 17 of Set 8 | vostok
# Processing Record 18 of Set 8 | guerrero negro
# Processing Record 19 of Set 8 | sibay
# Processing Record 20 of Set 8 | acin
# City not found. Skipping...
# Processing Record 21 of Set 8 | dingle
# Processing Record 22 of Set 8 | mlimba
# Processing Record 23 of Set 8 | coahuayana
# Processing Record 24 of Set 8 | fianga
# City not found. Skipping...
# Processing Record 25 of Set 8 | tiarei
# Processing Record 26 of Set 8 | trinidad
# Processing Record 27 of Set 8 | eucaliptus
# Processing Record 28 of Set 8 | yenagoa
# Processing Record 29 of Set 8 | northallerton
# Processing Record 30 of Set 8 | seydisehir
# Processing Record 31 of Set 8 | kenai
# Processing Record 32 of Set 8 | colares
# Processing Record 33 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 8 | wamba
# Processing Record 35 of Set 8 | rotifunk
# Processing Record 36 of Set 8 | stromness
# Processing Record 37 of Set 8 | thai nguyen
# Processing Record 38 of Set 8 | kazachinskoye
# Processing Record 39 of Set 8 | izumo
# Processing Record 40 of Set 8 | kuching
# Processing Record 41 of Set 8 | linhares
# Processing Record 42 of Set 8 | teguldet
# Processing Record 43 of Set 8 | saint-augustin
# Processing Record 44 of Set 8 | ossora
# Processing Record 45 of Set 8 | likhoslavl
# Processing Record 46 of Set 8 | paonta sahib
# Processing Record 47 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 48 of Set 8 | matsanga
# City not found. Skipping...
# Processing Record 49 of Set 8 | namatanai
# Processing Record 50 of Set 8 | bathsheba
# Processing Record 1 of Set 9 | zyryanka
# Processing Record 2 of Set 9 | anchorage
# Processing Record 3 of Set 9 | liverpool
# Processing Record 4 of Set 9 | pervomayskoye
# Processing Record 5 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 6 of Set 9 | linjiang
# Processing Record 7 of Set 9 | calabar
# Processing Record 8 of Set 9 | clyde river
# Processing Record 9 of Set 9 | baker city
# Processing Record 10 of Set 9 | mirabad
# Processing Record 11 of Set 9 | parana
# Processing Record 12 of Set 9 | gao
# Processing Record 13 of Set 9 | blackwater
# Processing Record 14 of Set 9 | hatillo
# Processing Record 15 of Set 9 | pudozh
# Processing Record 16 of Set 9 | tafresh
# Processing Record 17 of Set 9 | bowen
# Processing Record 18 of Set 9 | sabang
# Processing Record 19 of Set 9 | ginatilan
# Processing Record 20 of Set 9 | karauzyak
# City not found. Skipping...
# Processing Record 21 of Set 9 | tucurui
# Processing Record 22 of Set 9 | mehamn
# Processing Record 23 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 9 | mazyr
# Processing Record 25 of Set 9 | dronten
# Processing Record 26 of Set 9 | wakkanai
# Processing Record 27 of Set 9 | konstantinovka
# Processing Record 28 of Set 9 | saint-leu
# Processing Record 29 of Set 9 | chicama
# Processing Record 30 of Set 9 | cayenne
# Processing Record 31 of Set 9 | mergui
# City not found. Skipping...
# Processing Record 32 of Set 9 | ust-omchug
# Processing Record 33 of Set 9 | passo de camaragibe
# Processing Record 34 of Set 9 | komsomolskiy
# Processing Record 35 of Set 9 | goedereede
# Processing Record 36 of Set 9 | bantou
# Processing Record 37 of Set 9 | winnemucca
# Processing Record 38 of Set 9 | kalmunai
# Processing Record 39 of Set 9 | loiza
# Processing Record 40 of Set 9 | the valley
# Processing Record 41 of Set 9 | adrar
# Processing Record 42 of Set 9 | fjerritslev
# Processing Record 43 of Set 9 | altay
# Processing Record 44 of Set 9 | normandin
# Processing Record 45 of Set 9 | nova soure
# Processing Record 46 of Set 9 | nalut
# Processing Record 47 of Set 9 | torres
# Processing Record 48 of Set 9 | nang rong
# Processing Record 49 of Set 9 | bambanglipuro
# Processing Record 50 of Set 9 | waddan
# Processing Record 1 of Set 10 | banikoara
# Processing Record 2 of Set 10 | sobolevo
# Processing Record 3 of Set 10 | ukiah
# Processing Record 4 of Set 10 | tarakan
# Processing Record 5 of Set 10 | aswan
# Processing Record 6 of Set 10 | sioux lookout
# Processing Record 7 of Set 10 | alice springs
# Processing Record 8 of Set 10 | sandwick
# Processing Record 9 of Set 10 | kribi
# Processing Record 10 of Set 10 | emborion
# Processing Record 11 of Set 10 | luanda
# Processing Record 12 of Set 10 | havoysund
# Processing Record 13 of Set 10 | toppenish
# Processing Record 14 of Set 10 | saint george
# Processing Record 15 of Set 10 | korla
# Processing Record 16 of Set 10 | puerto leguizamo
# Processing Record 17 of Set 10 | bethel
# Processing Record 18 of Set 10 | asayita
# City not found. Skipping...
# Processing Record 19 of Set 10 | srednekolymsk
# Processing Record 20 of Set 10 | kemi
# Processing Record 21 of Set 10 | leningradskiy
# Processing Record 22 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 10 | romny
# Processing Record 24 of Set 10 | wonthaggi
# Processing Record 25 of Set 10 | ennis
# Processing Record 26 of Set 10 | fuyu
# Processing Record 27 of Set 10 | eyemouth
# Processing Record 28 of Set 10 | balabac
# Processing Record 29 of Set 10 | pokhara
# Processing Record 30 of Set 10 | shelburne
# Processing Record 31 of Set 10 | mantua
# Processing Record 32 of Set 10 | gawler
# Processing Record 33 of Set 10 | miri
# Processing Record 34 of Set 10 | jalu
# Processing Record 35 of Set 10 | kjollefjord
# Processing Record 36 of Set 10 | oktyabrskiy
# Processing Record 37 of Set 10 | innisfail
# Processing Record 38 of Set 10 | chandur bazar
# Processing Record 39 of Set 10 | naliya
# Processing Record 40 of Set 10 | porto novo
# Processing Record 41 of Set 10 | saint anthony
# Processing Record 42 of Set 10 | rubio
# Processing Record 43 of Set 10 | victor harbor
# Processing Record 44 of Set 10 | anar darreh
# City not found. Skipping...
# Processing Record 45 of Set 10 | saint-andre-avellin
# Processing Record 46 of Set 10 | namie
# Processing Record 47 of Set 10 | calvinia
# Processing Record 48 of Set 10 | suixi
# Processing Record 49 of Set 10 | buala
# Processing Record 50 of Set 10 | soto la marina
# Processing Record 1 of Set 11 | kumluca
# Processing Record 2 of Set 11 | atbasar
# Processing Record 3 of Set 11 | tecolutilla
# Processing Record 4 of Set 11 | prince rupert
# Processing Record 5 of Set 11 | mayo
# Processing Record 6 of Set 11 | cap malheureux
# Processing Record 7 of Set 11 | ostrovnoy
# Processing Record 8 of Set 11 | yumen
# Processing Record 9 of Set 11 | pekalongan
# Processing Record 10 of Set 11 | the pas
# Processing Record 11 of Set 11 | north bend
# Processing Record 12 of Set 11 | fukue
# Processing Record 13 of Set 11 | dunda
# Processing Record 14 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 15 of Set 11 | ovalle
# Processing Record 16 of Set 11 | kalabo
# Processing Record 17 of Set 11 | aykhal
# Processing Record 18 of Set 11 | svobodnyy
# Processing Record 19 of Set 11 | lata
# Processing Record 20 of Set 11 | sorland
# Processing Record 21 of Set 11 | olafsvik
# Processing Record 22 of Set 11 | ulladulla
# Processing Record 23 of Set 11 | sunel
# Processing Record 24 of Set 11 | pueblorrico
# Processing Record 25 of Set 11 | luena
# Processing Record 26 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 27 of Set 11 | pevek
# Processing Record 28 of Set 11 | hurricane
# Processing Record 29 of Set 11 | reinosa
# Processing Record 30 of Set 11 | revelstoke
# Processing Record 31 of Set 11 | port lincoln
# Processing Record 32 of Set 11 | bandar-e anzali
# Processing Record 33 of Set 11 | bealanana
# Processing Record 34 of Set 11 | babai
# Processing Record 35 of Set 11 | sisimiut
# Processing Record 36 of Set 11 | taltal
# Processing Record 37 of Set 11 | arcata
# Processing Record 38 of Set 11 | santa isabel do rio negro
# Processing Record 39 of Set 11 | waipawa
# Processing Record 40 of Set 11 | mount pleasant
# Processing Record 41 of Set 11 | gemena
# Processing Record 42 of Set 11 | passo fundo
# Processing Record 43 of Set 11 | graciano sanchez
# Processing Record 44 of Set 11 | maputo
# Processing Record 45 of Set 11 | nizhniy odes
# Processing Record 46 of Set 11 | bakau
# Processing Record 47 of Set 11 | harbour breton
# Processing Record 48 of Set 11 | akyab
# Processing Record 49 of Set 11 | gravdal
# Processing Record 50 of Set 11 | minjur
# Processing Record 1 of Set 12 | yelovo
# Processing Record 2 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 3 of Set 12 | honningsvag
# Processing Record 4 of Set 12 | bud
# Processing Record 5 of Set 12 | ahipara
# Processing Record 6 of Set 12 | balkhash
# Processing Record 7 of Set 12 | quatre cocos
# Processing Record 8 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 9 of Set 12 | tongren
# Processing Record 10 of Set 12 | cocal
# Processing Record 11 of Set 12 | coihaique
# Processing Record 12 of Set 12 | indramayu
# Processing Record 13 of Set 12 | eyl
# Processing Record 14 of Set 12 | novocheremshansk
# Processing Record 15 of Set 12 | douglas
# Processing Record 16 of Set 12 | palu
# Processing Record 17 of Set 12 | parras
# City not found. Skipping...
# Processing Record 18 of Set 12 | fasa
# Processing Record 19 of Set 12 | ayan
# Processing Record 20 of Set 12 | esso
# Processing Record 21 of Set 12 | benguela
# Processing Record 22 of Set 12 | sulangan
# Processing Record 23 of Set 12 | totness
# Processing Record 24 of Set 12 | labytnangi
# Processing Record 25 of Set 12 | santa barbara
# Processing Record 26 of Set 12 | seryshevo
# Processing Record 27 of Set 12 | tubuala
# Processing Record 28 of Set 12 | polunochnoye
# Processing Record 29 of Set 12 | kambove
# Processing Record 30 of Set 12 | muzhi
# Processing Record 31 of Set 12 | inhambane
# Processing Record 32 of Set 12 | caravelas
# Processing Record 33 of Set 12 | pundaguitan
# Processing Record 34 of Set 12 | kasongo
# Processing Record 35 of Set 12 | omsukchan
# Processing Record 36 of Set 12 | erzurum
# Processing Record 37 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 38 of Set 12 | jiangyou
# Processing Record 39 of Set 12 | kashi
# Processing Record 40 of Set 12 | galanta
# Processing Record 41 of Set 12 | barranca
# Processing Record 42 of Set 12 | maghama
# City not found. Skipping...
# Processing Record 43 of Set 12 | elko
# Processing Record 44 of Set 12 | portobelo
# Processing Record 45 of Set 12 | cherskiy
# Processing Record 46 of Set 12 | seymchan
# Processing Record 47 of Set 12 | sibolga
# Processing Record 48 of Set 12 | ambilobe
# Processing Record 49 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 50 of Set 12 | mathbaria
# Processing Record 1 of Set 13 | peruibe
# Processing Record 2 of Set 13 | jalingo
# Processing Record 3 of Set 13 | natal
# Processing Record 4 of Set 13 | camopi
# Processing Record 5 of Set 13 | andenes
# Processing Record 6 of Set 13 | champerico
# Processing Record 7 of Set 13 | tiznit
# Processing Record 8 of Set 13 | buraydah
# Processing Record 9 of Set 13 | peru
# Processing Record 10 of Set 13 | samarai
# Processing Record 11 of Set 13 | puerto escondido
# Processing Record 12 of Set 13 | taoudenni
# Processing Record 13 of Set 13 | northam
# Processing Record 14 of Set 13 | hohhot
# Processing Record 15 of Set 13 | lewiston
# Processing Record 16 of Set 13 | zhanaozen
# Processing Record 17 of Set 13 | merauke
# Processing Record 18 of Set 13 | olathe
# Processing Record 19 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 20 of Set 13 | batagay-alyta
# Processing Record 21 of Set 13 | hare bay
# Processing Record 22 of Set 13 | palmdale
# Processing Record 23 of Set 13 | husavik
# Processing Record 24 of Set 13 | padong
# Processing Record 25 of Set 13 | puerto quijarro
# Processing Record 26 of Set 13 | udachnyy
# Processing Record 27 of Set 13 | punta cardon
# Processing Record 28 of Set 13 | shyryayeve
# Processing Record 29 of Set 13 | san vicente
# Processing Record 30 of Set 13 | half moon bay
# Processing Record 31 of Set 13 | gijon
# Processing Record 32 of Set 13 | zlobin
# Processing Record 33 of Set 13 | shimoda
# Processing Record 34 of Set 13 | peschanokopskoye
# Processing Record 35 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 13 | matadi
# Processing Record 37 of Set 13 | soyo
# Processing Record 38 of Set 13 | tipuani
# Processing Record 39 of Set 13 | cabinda
# Processing Record 40 of Set 13 | anadyr
# Processing Record 41 of Set 13 | santa cruz
# Processing Record 42 of Set 13 | yabelo
# Processing Record 43 of Set 13 | paita
# Processing Record 44 of Set 13 | manaure
# Processing Record 45 of Set 13 | junnar
# Processing Record 46 of Set 13 | raudeberg
# Processing Record 47 of Set 13 | rodrigues alves
# Processing Record 48 of Set 13 | christchurch
# Processing Record 49 of Set 13 | denpasar
# Processing Record 50 of Set 13 | iztapa
# Processing Record 1 of Set 14 | perm
# Processing Record 2 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 3 of Set 14 | ayia galini
# Processing Record 4 of Set 14 | hay river
# Processing Record 5 of Set 14 | picton
# Processing Record 6 of Set 14 | banjar
# Processing Record 7 of Set 14 | pisco
# Processing Record 8 of Set 14 | aitape
# Processing Record 9 of Set 14 | avera
# Processing Record 10 of Set 14 | la asuncion
# Processing Record 11 of Set 14 | cotmeana
# Processing Record 12 of Set 14 | constitucion
# Processing Record 13 of Set 14 | cardston
# Processing Record 14 of Set 14 | hovd
# Processing Record 15 of Set 14 | bata
# Processing Record 16 of Set 14 | dawson
# Processing Record 17 of Set 14 | salvador
# Processing Record 18 of Set 14 | rangapara
# Processing Record 19 of Set 14 | kapuskasing
# Processing Record 20 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 21 of Set 14 | lourdes
# Processing Record 22 of Set 14 | namwala
# Processing Record 23 of Set 14 | praia
# Processing Record 24 of Set 14 | tidore
# City not found. Skipping...
# Processing Record 25 of Set 14 | nantucket
# Processing Record 26 of Set 14 | griffith
# Processing Record 27 of Set 14 | lekoni
# Processing Record 28 of Set 14 | cao bang
# Processing Record 29 of Set 14 | west fargo
# Processing Record 30 of Set 14 | lisakovsk
# Processing Record 31 of Set 14 | guiren
# Processing Record 32 of Set 14 | san carlos de bariloche
# Processing Record 33 of Set 14 | mitu
# Processing Record 34 of Set 14 | smithers
# Processing Record 35 of Set 14 | xining
# Processing Record 36 of Set 14 | dali
# Processing Record 37 of Set 14 | ulaangom
# Processing Record 38 of Set 14 | coos bay
# Processing Record 39 of Set 14 | sovetskiy
# Processing Record 40 of Set 14 | ningan
# City not found. Skipping...
# Processing Record 41 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 42 of Set 14 | berdigestyakh
# Processing Record 43 of Set 14 | mopipi
# Processing Record 44 of Set 14 | alta floresta
# Processing Record 45 of Set 14 | vangaindrano
# Processing Record 46 of Set 14 | yithion
# City not found. Skipping...
# Processing Record 47 of Set 14 | boyarka
# Processing Record 48 of Set 14 | port lavaca
# Processing Record 49 of Set 14 | nara
# Processing Record 50 of Set 14 | zarinsk
# Processing Record 1 of Set 15 | betsiamites
# Processing Record 2 of Set 15 | lasa
# Processing Record 3 of Set 15 | nadym
# Processing Record 4 of Set 15 | albertville
# Processing Record 5 of Set 15 | araci
# Processing Record 6 of Set 15 | yarada
# Processing Record 7 of Set 15 | ponta delgada
# Processing Record 8 of Set 15 | tilichiki
# Processing Record 9 of Set 15 | havre-saint-pierre
# Processing Record 10 of Set 15 | taungdwingyi
# Processing Record 11 of Set 15 | ardakan
# Processing Record 12 of Set 15 | san quintin
# Processing Record 13 of Set 15 | nizwa
# Processing Record 14 of Set 15 | praya
# Processing Record 15 of Set 15 | launceston
# Processing Record 16 of Set 15 | allapalli
# Processing Record 17 of Set 15 | labuhan
# Processing Record 18 of Set 15 | nouadhibou
# Processing Record 19 of Set 15 | akdepe
# Processing Record 20 of Set 15 | bandar-e lengeh
# Processing Record 21 of Set 15 | suntar
# Processing Record 22 of Set 15 | cranbourne
# Processing Record 23 of Set 15 | mongu
# Processing Record 24 of Set 15 | mizan teferi
# Processing Record 25 of Set 15 | marquette
# Processing Record 26 of Set 15 | noumea
# Processing Record 27 of Set 15 | borba
# Processing Record 28 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 29 of Set 15 | kaeo
# Processing Record 30 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 31 of Set 15 | urumqi
# Processing Record 32 of Set 15 | creston
# Processing Record 33 of Set 15 | eureka
# Processing Record 34 of Set 15 | jumla
# Processing Record 35 of Set 15 | morgan city
# Processing Record 36 of Set 15 | pascagoula
# Processing Record 37 of Set 15 | kangaba
# Processing Record 38 of Set 15 | bardiyah
# Processing Record 39 of Set 15 | renqiu
# Processing Record 40 of Set 15 | wawina
# Processing Record 41 of Set 15 | alyangula
# Processing Record 42 of Set 15 | nehe
# Processing Record 43 of Set 15 | cazaje
# City not found. Skipping...
# Processing Record 44 of Set 15 | dubrovnik
# Processing Record 45 of Set 15 | ambon
# Processing Record 46 of Set 15 | zinder
# Processing Record 47 of Set 15 | galiwinku
# City not found. Skipping...
# Processing Record 48 of Set 15 | umred
# Processing Record 49 of Set 15 | moree
# Processing Record 50 of Set 15 | pringsewu
# Processing Record 1 of Set 16 | campbell river
# Processing Record 2 of Set 16 | abu dhabi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0  Port Elizabeth      ZA -33.92   25.57     64.00        82          19
# 1           Jiazi      CN  22.88  116.07     68.52        63          99
# 2         Rikitea      PF -23.12 -134.97     74.64        83          84
# 3            Hami      CN  42.80   93.45     46.51        52          86
# 4         Lincoln      US  40.80  -96.67     35.60        64          90
# 5            Asau      RO  46.43   26.40     53.01        98         100
# 6      Butaritari      KI   3.07  172.79     82.06        66          18
# 7        Antalaha      MG -14.90   50.28     70.57        86           2
# 8       Cape Town      ZA -33.93   18.42     61.00        93          20
# 9          Torbay      CA  47.67  -52.73     48.99        93          90
#
#    Wind Speed Current Description
# 0        1.01          few clouds
# 1       20.13     overcast clouds
# 2       22.82       broken clouds
# 3        8.57     overcast clouds
# 4        9.17     overcast clouds
# 5        2.53          light rain
# 6        7.07          few clouds
# 7        7.27           clear sky
# 8        3.36          few clouds
# 9       27.51     overcast clouds

# %%
output_data_file = "WeatherPy_Database.csv"

city_data_df.to_csv(output_data_file, index_label="City ID")
